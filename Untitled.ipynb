# %%
import geopandas as gpd 
import matplotlib.pyplot as plt
import csv
import shapely 

bike_priority_districts = gpd.read_file('/Users/jtzandi/Desktop/visionzero/data/bike_priority_districts.json')
bike_priority_districts


x = bike_priority_districts['geometry']
x.plot()

plt.show()

# %%
x = 0 
for zone in bpd_geo: 
    if not zone.contains(point):
        x = 0
        pass
    else:
        x = 1
        break 
write(x)
